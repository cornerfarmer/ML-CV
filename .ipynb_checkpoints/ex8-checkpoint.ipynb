# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
sigma_f = 1
l = 0.1
sigma_n = 0.1

# %%
def gaussian_kernel(x1, x2):
    return sigma_f * sigma_f * np.exp(-1 / (2 * l * l) * (x1 - x2) ** 2) + sigma_n * sigma_n * (x1 == x2)

def rbfkernel(x, y) :
    return sigmaf ** 2 * np.exp(-(x - y)**2 / (2 * l ** 2 )) + sigma_n ** 2 * (x == y)

# %%
sigmanoise = 0.5
xmin, xmax = -5, 5
Xtrain = np.linspace(xmin, xmax, num=10)
Ytrain= [10 * np.sin(x) + (np.random.rand() - 0.5) * sigmanoise for x in Xtrain]

fig = plt.figure()
ax = plt.axes()
ax.plot(Xtrain, Ytrain)

# %%
Xtrain1 = np.resize(Xtrain, [Xtrain.shape[0]] * 2)
Xtrain2 = np.transpose(Xtrain1)
K = kernel(Xtrain1, Xtrain2)
L = np.linalg.cholesky(K + sigma_n * sigma_n)
alpha = np.linalg.solve(np.transpose(L), np.linalg.solve(L, Ytrain))

# %%
Xtest = np.arange(-1, 1, 0.01)
Xtest1 = np.resize(Xtest, [Xtest.shape[0], Xtrain.shape[0]])
k_star = kernel(np.resize(Xtrain, [Xtrain.shape[0], Xtest.shape[0]] * 2), Xtest1.T)

# %%
fig = plt.figure()
ax = plt.axes()
ax.set_ylim(-3, 3)

for i in range(5):
    x = np.arange(-1, 1, 0.01)
    X1 = np.resize(x, [x.shape[0]] * 2)
    X2 = np.transpose(X1)
    K = kernel(X1, X2)
    y = np.random.multivariate_normal([0] * K.shape[0], K)

    ax.plot(x, y)
